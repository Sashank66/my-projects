# %%
import pandas as pd

# %%
df=pd.read_csv('Lending-company.csv')
df
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
# ...

# %%
df.isnull()
# Out:
#       LoanID  StringID  Product  CustomerGender  Location  Region  TotalPrice  \
# 0      False     False    False           False     False   False       False
# 1      False     False    False           False     False   False        True
# 2      False     False    False           False     False   False       False
# 3      False     False    False           False     False   False       False
# 4      False     False    False           False     False   False       False
# ...      ...       ...      ...             ...       ...     ...         ...
# 1038   False     False    False           False     False   False       False
# 1039   False     False    False           False     False   False        True
# 1040   False     False    False           False     False   False       False
# 1041   False     False    False           False     False   False       False
# 1042   False     False    False           False     False   False       False
#
# ...

# %%
df.isnull().sum()
# Out:
# LoanID             0
# StringID           0
# Product            0
# CustomerGender     0
# Location           0
# Region             1
# TotalPrice        25
# StartDate          1
# Deposit            0
# DailyRate          0
# TotalDaysYr        0
# AmtPaid36          0
# AmtPaid60          0
# AmtPaid360         0
# LoanStatus        37
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 64

# %%
df.dtypes
# Out:
# LoanID              int64
# StringID           object
# Product            object
# CustomerGender     object
# Location           object
# Region             object
# TotalPrice        float64
# StartDate          object
# Deposit             int64
# DailyRate           int64
# TotalDaysYr         int64
# AmtPaid36           int64
# AmtPaid60           int64
# AmtPaid360          int64
# LoanStatus         object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1043 entries, 0 to 1042
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   LoanID          1043 non-null   int64
#  1   StringID        1043 non-null   object
#  2   Product         1043 non-null   object
#  3   CustomerGender  1043 non-null   object
#  4   Location        1043 non-null   object
#  5   Region          1042 non-null   object
#  6   TotalPrice      1018 non-null   float64
#  7   StartDate       1042 non-null   object
#  8   Deposit         1043 non-null   int64
#  9   DailyRate       1043 non-null   int64
#  10  TotalDaysYr     1043 non-null   int64
#  11  AmtPaid36       1043 non-null   int64
#  12  AmtPaid60       1043 non-null   int64
#  13  AmtPaid360      1043 non-null   int64
#  14  LoanStatus      1006 non-null   object
# dtypes: float64(1), int64(7), object(7)
# memory usage: 122.4+ KB

# %%
df.head()
# Out:
#    LoanID  StringID    Product CustomerGender     Location    Region  \
# 0       1  LoanID_1  Product B         Female   Location 3  Region 2
# 1       2  LoanID_2  Product D         Female   Location 6  Region 6
# 2       3  LoanID_3  Product B           Male   Location 8  Region 3
# 3       4  LoanID_4  Product A           Male  Location 26  Region 2
# 4       5  LoanID_5  Product B         Female  Location 34  Region 3
#
#    TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# 0     17600.0  04/07/2018     2200         45          365       3221
# 1         NaN  02/01/2019     2200         45          365       3161
# 2     16600.0  08/12/2016     1000         45          365       2260
# 3     17600.0         NaN     2200         45          365       3141
# 4     21250.0  28/10/2017     2200         55          365       3570
#
#    AmtPaid60  AmtPaid360 LoanStatus
# 0       4166       14621     Active
# 1       4096       16041     Active
# ...

# %%
df.isnull().sum()
# Out:
# LoanID             0
# StringID           0
# Product            0
# CustomerGender     0
# Location           0
# Region             1
# TotalPrice        25
# StartDate          1
# Deposit            0
# DailyRate          0
# TotalDaysYr        0
# AmtPaid36          0
# AmtPaid60          0
# AmtPaid360         0
# LoanStatus        37
# dtype: int64

# %%
df[df.TotalPrice.isna()]
# Out:
#       LoanID     StringID    Product CustomerGender      Location    Region  \
# 1          2     LoanID_2  Product D         Female    Location 6  Region 6
# 5          6     LoanID_6  Product A           Male   Location 34  Region 1
# 56        57    LoanID_57  Product B         Female   Location 10  Region 6
# 90        91    LoanID_91  Product A           Male  Location 186  Region 7
# 160      161   LoanID_161  Product A           Male  Location 377  Region 3
# 220      221   LoanID_221  Product B           Male   Location 25  Region 7
# 270      271   LoanID_271  Product A         Female   Location 91  Region 2
# 330      331   LoanID_331  Product A         Female   Location 46  Region 3
# 380      381   LoanID_381  Product A           Male  Location 161  Region 3
# 430      431   LoanID_431  Product A         Female    Location 3  Region 2
# 470      471   LoanID_471  Product B         Female  Location 296  Region 1
# ...

# %%
df.TotalPrice.mean()
# Out:
# 19562.84381139489

# %%
df.fillna(df.TotalPrice.mean(), inplace=True)

# %%
df.TotalPrice
# Out:
# 0                17600.0
# 1       Finished Payment
# 2                16600.0
# 3                17600.0
# 4                21250.0
#               ...
# 1038             17300.0
# 1039    Finished Payment
# 1040             17300.0
# 1041             16300.0
# 1042             17300.0
# Name: TotalPrice, Length: 1043, dtype: object

# %%
df
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
# ...

# %%
df[df.LoanStatus.isnull()]
# Out:
#       LoanID     StringID    Product CustomerGender      Location    Region  \
# 2          3     LoanID_3  Product B           Male    Location 8  Region 3
# 8          9     LoanID_9  Product A           Male  Location 156  Region 6
# 57        58    LoanID_58  Product B           Male   Location 53  Region 2
# 89        90    LoanID_90  Product B           Male   Location 17  Region 3
# 126      127   LoanID_127  Product A           Male   Location 89  Region 2
# 159      160   LoanID_160  Product C         Female   Location 70  Region 3
# 192      193   LoanID_193  Product B           Male   Location 94  Region 6
# 228      229   LoanID_229  Product B           Male   Location 34  Region 3
# 235      236   LoanID_236  Product A           Male  Location 177  Region 2
# 262      263   LoanID_263  Product B           Male   Location 45  Region 5
# 282      283   LoanID_283  Product A           Male    Location 3  Region 6
# ...

# %%
df.LoanStatus.mode()
# Out:
# 0    Finished Payment
# Name: LoanStatus, dtype: object

# %%
df.fillna(df.LoanStatus.mode()[0], inplace=True)

# %%
df.LoanStatus
# Out:
# 0                 Active
# 1                 Active
# 2           19562.843811
# 3                 Active
# 4                 Active
#               ...
# 1038    Finished Payment
# 1039    Finished Payment
# 1040    Finished Payment
# 1041    Finished Payment
# 1042    Finished Payment
# Name: LoanStatus, Length: 1043, dtype: object

# %%
df.isna().sum()
# Out:
# LoanID            0
# StringID          0
# Product           0
# CustomerGender    0
# Location          0
# Region            0
# TotalPrice        0
# StartDate         0
# Deposit           0
# DailyRate         0
# TotalDaysYr       0
# AmtPaid36         0
# AmtPaid60         0
# AmtPaid360        0
# LoanStatus        0
# dtype: int64

# %%
df[df.Region.isna()]
# Out:
# Empty DataFrame
# Columns: [LoanID, StringID, Product, CustomerGender, Location, Region, TotalPrice, StartDate, Deposit, DailyRate, TotalDaysYr, AmtPaid36, AmtPaid60, AmtPaid360, LoanStatus]
# Index: []

# %%
df.Region.mode()
# Out:
# 0    Region 6
# Name: Region, dtype: object

# %%
df.fillna(df.Region.mode(), inplace=True)

# %%
df
# Out:
#       LoanID     StringID    Product CustomerGender     Location    Region  \
# 0          1     LoanID_1  Product B         Female   Location 3  Region 2
# 1          2     LoanID_2  Product D         Female   Location 6  Region 6
# 2          3     LoanID_3  Product B           Male   Location 8  Region 3
# 3          4     LoanID_4  Product A           Male  Location 26  Region 2
# 4          5     LoanID_5  Product B         Female  Location 34  Region 3
# ...      ...          ...        ...            ...          ...       ...
# 1038    1039  LoanID_1039  Product B           Male  Location 73  Region 6
# 1039    1040  LoanID_1040  Product A           Male  Location 82  Region 1
# 1040    1041  LoanID_1041  Product A   NotSpecified  Location 11  Region 4
# 1041    1042  LoanID_1042  Product B         Female  Location 26  Region 6
# 1042    1043  LoanID_1043  Product A   NotSpecified  Location 94  Region 6
#
# ...

# %%
df.isna().sum()
# Out:
# LoanID            0
# StringID          0
# Product           0
# CustomerGender    0
# Location          0
# Region            0
# TotalPrice        0
# StartDate         0
# Deposit           0
# DailyRate         0
# TotalDaysYr       0
# AmtPaid36         0
# AmtPaid60         0
# AmtPaid360        0
# LoanStatus        0
# dtype: int64
